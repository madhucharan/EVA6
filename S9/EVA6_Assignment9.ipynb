# %%
! pip install torchsummary
! pip install -U git+https://github.com/albu/albumentations --no-cache-dir
# Out:
# ...
#   Cloning https://github.com/albu/albumentations to /tmp/pip-req-build-7mjlnw62
#   Running command git clone -q https://github.com/albu/albumentations /tmp/pip-req-build-7mjlnw62
# ...
#   Created wheel for albumentations: filename=albumentations-1.0.2-cp37-none-any.whl size=98521 sha256=33d1ab412081678404b3963722d9c4d7ff25b55485c9f8b5ab2588c49d8c4d98
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l1o1k34h/wheels/45/8b/e4/2837bbcf517d00732b8e394f8646f22b8723ac00993230188b
# Successfully built albumentations
# ...
#   Found existing installation: albumentations 1.0.2
#     Uninstalling albumentations-1.0.2:
#       Successfully uninstalled albumentations-1.0.2
# ...

# %%
# !git clone https://github.com/aggarwalsiddharth/custom_resnet.git /content/drive/MyDrive/custom_resnet/files
# Out:
# Cloning into '/content/drive/MyDrive/custom_resnet/files'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 43 (delta 24), reused 33 (delta 14), pack-reused 0
# Unpacking objects: 100% (43/43), done.

# %%
# %cd "/content/drive/MyDrive/custom_resnet/files"
# Out:
# /content/drive/MyDrive/custom_resnet/files

# %%
# %ls
# Out:
# lr_module.py  main.py  model.py  utils.py

# %%
% run main.py
# Out:
# ----------Compute image mean & std----------
# Files already downloaded and verified
# [Train]
#  - Numpy Shape: (50000, 32, 32, 3)
#  - Tensor Shape: (50000, 32, 32, 3)
#  - min: 0
#  - max: 255
#
# Dataset Mean - [0.49139968 0.48215841 0.44653091]
# Dataset Std - [0.24703223 0.24348513 0.26158784]
# ----------Normailizing Images----------
# ----------Load and Transform Images----------
# /usr/local/lib/python3.7/dist-packages/albumentations/augmentations/transforms.py:690: FutureWarning: This class has been deprecated. Please use CoarseDropout
#   FutureWarning,
# Files already downloaded and verified
# Files already downloaded and verified
# CUDA Available? True
# ----------Device type - cuda----------
# ----------Model Summary----------
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
# ...
